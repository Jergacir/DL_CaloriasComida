# %% [markdown]
# **Modelo de Predicción Calorías - Ejecutado en Colab**

# %%
# ═══════════════════════════════════════════════════════════
# ENTRENAR MODELO 2 Y GUARDAR CORRECTAMENTE
# ═══════════════════════════════════════════════════════════

# 1. Setup
# !rm -rf /content/DL_CaloriasComida
# !git clone https://github.com/Jergacir/DL_CaloriasComida.git
# %cd DL_CaloriasComida

from google.colab import drive
drive.mount('/content/drive')

# 2. Entrenar
# !python src/modelo2/train_m2.py

# 3. Verificar archivos generados
print("\n📦 Verificando modelos:")
# !ls -lh modelos/

# 4. Copiar a Drive MANUALMENTE (por si acaso)
import shutil
import os

os.makedirs('/content/drive/MyDrive/DL_CaloriasComida/modelos', exist_ok=True)

if os.path.exists('modelos/modelo2_mejor.pth'):
    shutil.copy('modelos/modelo2_mejor.pth',
                '/content/drive/MyDrive/DL_CaloriasComida/modelos/')
    print("✓ modelo2_mejor.pth copiado a Drive")

if os.path.exists('modelos/modelo2_final.pth'):
    shutil.copy('modelos/modelo2_final.pth',
                '/content/drive/MyDrive/DL_CaloriasComida/modelos/')
    print("✓ modelo2_final.pth copiado a Drive")

print("\n✅ Modelos guardados en Drive")
